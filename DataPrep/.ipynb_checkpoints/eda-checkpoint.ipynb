# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
csv_filename = "../CleanData/master_set_with_imputation_4_27_25.csv"
df = pd.read_csv(csv_filename)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91210 entries, 0 to 91209
# Data columns (total 30 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   n                     91210 non-null  int64
#  1   gid                   91210 non-null  object
#  2   visteam               91210 non-null  object
#  3   hometeam              91210 non-null  object
#  4   site                  91210 non-null  object
#  5   number                91210 non-null  float64
#  6   daynight              91210 non-null  int64
#  7   attendance            91210 non-null  int64
#  8   temp                  91210 non-null  float64
#  9   windspeed             91210 non-null  float64
#  10  season                91210 non-null  int64
#  11  vruns                 91210 non-null  int64
#  12  hruns                 91210 non-null  int64
#  13  wteam                 91210 non-null  object
#  14  lteam                 91210 non-null  object
#  15  team                  91210 non-null  object
#  16  Home_Away             91210 non-null  int64
#  17  score_diff            91210 non-null  int64
#  18  left_on_base          91210 non-null  float64
#  19  bat_doubles           91210 non-null  float64
#  20  bat_triples           91210 non-null  float64
#  21  bat_home_runs         91210 non-null  float64
#  22  bat_stolen_bases      91210 non-null  float64
#  23  passed_balls_allowed  91210 non-null  float64
#  24  errors_committed      91210 non-null  float64
#  25  stolen_bases          91210 non-null  float64
#  26  date                  91210 non-null  object
#  27  yearID                91210 non-null  int64
#  28  teamID                91210 non-null  object
#  29  salary                91210 non-null  float64
# dtypes: float64(12), int64(9), object(9)
# memory usage: 20.9+ MB

# %%
# convert some column types into int
df = df.drop(columns=['n', 'number'])  # remove redundant columns
for col in ['left_on_base', 'bat_doubles', 'bat_triples', 'bat_home_runs', 'bat_stolen_bases', 'passed_balls_allowed', 'errors_committed', 'stolen_bases', 'salary', 'score_diff']:
    df[col] = df[col].astype(int)

for col in ['gid', 'visteam', 'hometeam', 'site', 'wteam', 'lteam', 'team', 'teamID']:
    df[col] = df[col].astype('category')

df['date'] = pd.to_datetime(df['date'])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91210 entries, 0 to 91209
# Data columns (total 28 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   gid                   91210 non-null  category
#  1   visteam               91210 non-null  category
#  2   hometeam              91210 non-null  category
#  3   site                  91210 non-null  category
#  4   daynight              91210 non-null  int64
#  5   attendance            91210 non-null  int64
#  6   temp                  91210 non-null  float64
#  7   windspeed             91210 non-null  float64
#  8   season                91210 non-null  int64
#  9   vruns                 91210 non-null  int64
#  10  hruns                 91210 non-null  int64
#  11  wteam                 91210 non-null  category
#  12  lteam                 91210 non-null  category
#  13  team                  91210 non-null  category
#  14  Home_Away             91210 non-null  int64
#  15  score_diff            91210 non-null  int64
#  16  left_on_base          91210 non-null  int64
#  17  bat_doubles           91210 non-null  int64
#  18  bat_triples           91210 non-null  int64
#  19  bat_home_runs         91210 non-null  int64
#  20  bat_stolen_bases      91210 non-null  int64
#  21  passed_balls_allowed  91210 non-null  int64
#  22  errors_committed      91210 non-null  int64
#  23  stolen_bases          91210 non-null  int64
#  24  date                  91210 non-null  datetime64[ns]
#  25  yearID                91210 non-null  int64
#  26  teamID                91210 non-null  category
#  27  salary                91210 non-null  int64
# dtypes: category(8), datetime64[ns](1), float64(2), int64(17)
# memory usage: 17.6 MB

# %%
# check nulls
df.isna().sum()
# Out:
# gid                     0
# visteam                 0
# hometeam                0
# site                    0
# daynight                0
# attendance              0
# temp                    0
# windspeed               0
# season                  0
# vruns                   0
# hruns                   0
# wteam                   0
# lteam                   0
# team                    0
# Home_Away               0
# score_diff              0
# left_on_base            0
# bat_doubles             0
# bat_triples             0
# bat_home_runs           0
# bat_stolen_bases        0
# passed_balls_allowed    0
# errors_committed        0
# stolen_bases            0
# date                    0
# yearID                  0
# teamID                  0
# salary                  0
# dtype: int64

# %%
# summary stats
df.describe(include='all')
# Out:
#                  gid visteam hometeam   site      daynight    attendance  \
# count          91210   91210    91210  91210  91210.000000  91210.000000
# unique         91209      33       33     72           NaN           NaN
# top     ATL198605200     SEA      SFN  ANA01           NaN           NaN
# freq               2    3161     3164   3163           NaN           NaN
# mean             NaN     NaN      NaN    NaN      0.330687  28694.631795
# min              NaN     NaN      NaN    NaN      0.000000    746.000000
# 25%              NaN     NaN      NaN    NaN      0.000000  19667.000000
# 50%              NaN     NaN      NaN    NaN      0.000000  28621.000000
# 75%              NaN     NaN      NaN    NaN      1.000000  37721.750000
# max              NaN     NaN      NaN    NaN      1.000000  80227.000000
# std              NaN     NaN      NaN    NaN      0.470463  11507.447540
#
#                 temp     windspeed        season        vruns  ...  \
# count   91210.000000  91210.000000  91210.000000  91210.00000  ...
# unique           NaN           NaN           NaN          NaN  ...
# top              NaN           NaN           NaN          NaN  ...
# freq             NaN           NaN           NaN          NaN  ...
# mean       70.755083      6.826780   2004.883072      4.49954  ...
# min        16.409742     -1.000000   1985.000000      0.00000  ...
# 25%        64.000000      2.057477   1996.000000      2.00000  ...
# 50%        72.000000      7.000000   2005.000000      4.00000  ...
# 75%        79.000000     10.000000   2014.000000      6.00000  ...
# max       113.000000     40.000000   2024.000000     30.00000  ...
# std        13.001473      5.669278     11.325744      3.19390  ...
#
#          bat_triples bat_home_runs bat_stolen_bases passed_balls_allowed  \
# count   91210.000000  91210.000000     91210.000000         91210.000000
# unique           NaN           NaN              NaN                  NaN
# top              NaN           NaN              NaN                  NaN
# freq             NaN           NaN              NaN                  NaN
# mean        0.186756      1.030764         0.631674             0.071483
# min         0.000000      0.000000         0.000000             0.000000
# 25%         0.000000      0.000000         0.000000             0.000000
# 50%         0.000000      1.000000         0.000000             0.000000
# 75%         0.000000      2.000000         1.000000             0.000000
# max         5.000000     10.000000        10.000000             5.000000
# std         0.441775      1.081631         0.937821             0.278334
#
#         errors_committed  stolen_bases                           date  \
# count       91210.000000  91210.000000                          91210
# unique               NaN           NaN                            NaN
# top                  NaN           NaN                            NaN
# freq                 NaN           NaN                            NaN
# mean            0.657307      0.635292  2005-05-22 03:12:41.363885696
# min             0.000000      0.000000            1985-04-08 00:00:00
# 25%             0.000000      0.000000            1996-04-11 00:00:00
# 50%             0.000000      0.000000            2005-07-20 00:00:00
# 75%             1.000000      1.000000            2014-09-23 00:00:00
# max             7.000000     10.000000            2024-09-30 00:00:00
# std             0.851964      0.938393                            NaN
#
#               yearID  teamID        salary
# count   91210.000000   91210  9.121000e+04
# unique           NaN      33           NaN
# top              NaN     SDN           NaN
# freq             NaN    3252           NaN
# mean     2004.883072     NaN  6.587325e+07
# min      1985.000000     NaN  8.800000e+05
# 25%      1996.000000     NaN  3.021050e+07
# 50%      2005.000000     NaN  5.680246e+07
# 75%      2014.000000     NaN  9.053685e+07
# max      2024.000000     NaN  2.603986e+08
# std        11.325744     NaN  4.600785e+07
#
# [11 rows x 28 columns]

# %%
# check if `gid` is unique
df['gid'].is_unique
# Out:
# False

# %%
# Find all duplicated gid values (keeping all instances, not just the second)
duplicates = df[df.duplicated('gid', keep=False)]
duplicates = duplicates.sort_values('gid')
duplicates.head()
# Out:
#                gid visteam hometeam   site  daynight  attendance       temp  \
# 2561  ATL198605200     CHN      ATL  ATL01         0       16925  47.180942
# 2562  ATL198605200     CHN      ATL  ATL01         0       16925  47.180942
#
#       windspeed  season  vruns  ...  bat_triples bat_home_runs  \
# 2561       -1.0    1986      3  ...            0             1
# 2562       -1.0    1986      3  ...            0             1
#
#      bat_stolen_bases passed_balls_allowed  errors_committed  stolen_bases  \
# 2561                1                    0                 3             0
# 2562                1                    0                 3             0
#
#            date  yearID  teamID    salary
# 2561 1986-05-20    1986     CHN  17208165
# 2562 1986-05-20    1986     CHN  17208165
#
# [2 rows x 28 columns]

# %% [markdown]
# There are 2 records identical: need to remove dupes

# %%
# remove duplicates based on `gid`
df = df.drop_duplicates(subset='gid', keep='first')

# %%
# Check if 'teamID' and 'team' are equal for all rows
team_match = (df['teamID'] == df['team']).all()
print(f"'teamID' == 'team' for all rows? {team_match}")
# Out:
# 'teamID' == 'team' for all rows? True

# %% [markdown]
# teamID and team columns are identical: we can keep only one

# %%
# Check if 'season' and 'yearID' are equal for all rows
season_match = (df['season'] == df['yearID']).all()
print(f"'season' == 'yearID' for all rows? {season_match}")
# Out:
# 'season' == 'yearID' for all rows? True

# %% [markdown]
# season and yearID columns are identical: we can keep only one

# %%
df = df.drop(columns=['team', 'season'])
df.head()
# Out:
#             gid visteam hometeam   site  daynight  attendance       temp  \
# 0  BAL198504080     TEX      BAL  BAL11         1       50402  39.635879
# 1  BOS198504080     NYA      BOS  BOS07         1       34282  63.309667
# 2  CIN198504080     MON      CIN  CIN08         1       52971  56.512982
# 3  DET198504080     CLE      DET  DET04         1       51180  42.000000
# 4  KCA198504080     TOR      KCA  KAN06         1       41086  69.690476
#
#    windspeed  vruns  hruns  ... bat_triples bat_home_runs  bat_stolen_bases  \
# 0       -1.0      2      4  ...           0             0                 0
# 1       -1.0      2      9  ...           0             0                 0
# 2       -1.0      1      4  ...           0             0                 3
# 3       13.0      4      5  ...           0             0                 1
# 4       -1.0      1      2  ...           0             0                 1
#
#    passed_balls_allowed  errors_committed  stolen_bases       date  yearID  \
# 0                     1                 0             0 1985-04-08    1985
# 1                     0                 0             1 1985-04-08    1985
# 2                     0                 0             0 1985-04-08    1985
# 3                     0                 0             1 1985-04-08    1985
# 4                     0                 1             0 1985-04-08    1985
#
#    teamID    salary
# 0     TEX   7676500
# 1     NYA  14238204
# 2     CIN   8359917
# 3     DET  10348143
# 4     TOR   8812550
#
# [5 rows x 26 columns]

# %%
invalid_winners = set((df['wteam'] == df['teamID']) & (df['score_diff'] < 0))
print(f"Invalid winners (where score is positive but team has lost)? {len(invalid_winners) > 1}")
# Out:
# Invalid winners (where score is positive but team has lost)? False

# %%
# Count frequencies of each home team
home_counts = df['hometeam'].value_counts()
sns.set_style("whitegrid")
plt.figure(figsize=(12, 6))
sns.barplot(x=home_counts.index, y=home_counts.values, palette="viridis", hue=home_counts.index, legend=False)

plt.xticks(rotation=90)
plt.title("Histogram of Home Team Appearances")
plt.xlabel("Home Team")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# %%
# Count frequencies of each winner team
winner_counts = df['wteam'].value_counts()
sns.set_style("whitegrid")
plt.figure(figsize=(12, 6))
sns.barplot(x=winner_counts.index, y=winner_counts.values, palette="viridis", hue=winner_counts.index, legend=False)

plt.xticks(rotation=90)
plt.title("Histogram of Winner Teams")
plt.xlabel("Winner Team")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# %%
# Count frequencies of each winner team
lost_counts = df['lteam'].value_counts()
sns.set_style("whitegrid")
plt.figure(figsize=(12, 6))
sns.barplot(x=lost_counts.index, y=lost_counts.values, palette="viridis", hue=lost_counts.index, legend=False)

plt.xticks(rotation=90)
plt.title("Histogram of Lost Teams")
plt.xlabel("Lost Team")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# %% [markdown]
# Weather analysis

# %%
# average and min/max temp and windspeed
summary = df[['temp', 'windspeed']].agg(['mean', 'std', 'min', 'max']).round(2)
print(summary)
# Out:
#         temp  windspeed
# mean   70.76       6.83
# std    13.00       5.67
# min    16.41      -1.00
# max   113.00      40.00

# %% [markdown]
# Correlation

# %%
correlation_matrix = df.corr(numeric_only=True)

# Move 'score_diff' to the diagonal position
cols = set(correlation_matrix.columns)
cols = ['score_diff'] + list(cols.difference(['score_diff']))
correlation_matrix = correlation_matrix[cols].loc[cols]

plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title("Correlation Matrix")
plt.tight_layout()
plt.show()

# %% [markdown]
# `bat_home_runs` seems like to have highest correlation.
# Does the day or night actually has any impact on score?

# %%
sns.set_style("whitegrid")

# Regression plot
sns.lmplot(
    data=df,
    x='bat_home_runs',
    y='score_diff',
    hue='daynight',
    height=6,
    aspect=1.5
)

plt.title("Regression of Score Diff vs Bat Home Runs (by Day/Night)")
plt.xlabel("Bat Home Runs")
plt.ylabel("Score Difference")
plt.tight_layout()
plt.show()

# no difference

# %% [markdown]
# #### APPLY PCA

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA


# correlation seems to be have between `score_diff` X ['bat_stolen_bases', 'left_on_base', 'Home_Away', 'bat_doubles', 'bat_triples', 'bat_home_runs', 'salary', 'stolen_bases', 'errors_committed', 'passed_balls_allowed']

columns_with_correlation = ['bat_stolen_bases', 'left_on_base', 'Home_Away', 'bat_doubles', 'bat_triples', 'bat_home_runs', 'salary', 'stolen_bases', 'errors_committed', 'passed_balls_allowed']

# pick only numeric columns for PCA
target = 'score_diff'
non_categorical_columns = []
categorical_columns = []
for c in df.columns:
    if c == target:
        continue
    if df[c].dtype == 'object' or df[c].dtype.name == 'category' or c == 'date':
        categorical_columns.append(c)
    else:
        non_categorical_columns.append(c)


# move yearID to the categorical
categorical_columns.append('yearID')
non_categorical_columns.remove('yearID')

print(f"Categorical columns: {categorical_columns}")
print(f"Non-categorical columns: {non_categorical_columns}")


X = df[non_categorical_columns]
y = df[target]

# Scale the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Apply PCA
pca = PCA(n_components=5)
X_pca = pca.fit_transform(X_scaled)

X_pca.shape
# Out:
# Categorical columns: ['gid', 'visteam', 'hometeam', 'site', 'wteam', 'lteam', 'date', 'teamID', 'yearID']
# Non-categorical columns: ['daynight', 'attendance', 'temp', 'windspeed', 'vruns', 'hruns', 'Home_Away', 'left_on_base', 'bat_doubles', 'bat_triples', 'bat_home_runs', 'bat_stolen_bases', 'passed_balls_allowed', 'errors_committed', 'stolen_bases', 'salary']
# (91209, 5)

# %%
# plot
for pca_com in range(pca.n_components_):
    sns.set_style("whitegrid")
    plt.figure(figsize=(8, 6))
    sns.regplot(x=X_pca[:, pca_com], y=y, scatter_kws={'alpha': 0.6}, line_kws={'color': 'red'})
    plt.title(f"Regression: PC{pca_com + 1} vs Score Diff")
    plt.xlabel(f"Principal Component {pca_com + 1}")
    plt.ylabel("Score Difference")
    plt.tight_layout()
    plt.show()

# %%
print(X_pca.shape, y.shape)
# Out:
# (91209, 5) (91209,)

# %%
# fit linear regression model and plot results
from statsmodels.formula.api import ols
from sklearn.model_selection import train_test_split

# X_train, X_test, y_train, y_test = train_test_split(X_pca, y, test_size=0.2, random_state=123)
pca_col_names = [f"PCA_{i}" for i in range(X_pca.shape[1])]
df_data = pd.DataFrame(X_pca, columns=pca_col_names)
df_categorical = df[categorical_columns + [target]]
df_categorical = df_categorical.reset_index(drop=True)
df_data = df_data.reset_index(drop=True)
df_data = pd.concat([df_data, df_categorical], axis=1)
# # save df_data
df_data.to_csv("../CleanData/df_data_with_pca.csv", index=False)
#
df_train, df_test = train_test_split(df_data, test_size=0.2, random_state=123)
# # train_data = pd.concat([X_train, y_train], axis=1)
df_train.head()
# Out:
#           PCA_0     PCA_1     PCA_2     PCA_3     PCA_4           gid visteam  \
# 56877  1.785259 -0.407204  0.810983 -0.431894 -0.352401  DET201005150     BOS
# 68728  1.247072 -1.697574 -1.980454 -2.514632  0.447867  TBA201504240     TOR
# 79901  0.205793  1.580729  1.572966 -0.089935  0.549213  SFN201908070     WAS
# 17433 -2.035450 -1.575162 -0.928343 -1.904423  1.956604  MON199305260     SLN
# 9733  -1.457633 -0.660227  0.398878  0.031353  1.827572  MON198907300     SLN
#
#       hometeam   site wteam lteam       date teamID  yearID  score_diff
# 56877      DET  DET05   DET   BOS 2010-05-15    DET    2010           1
# 68728      TBA  STP01   TBA   TOR 2015-04-24    TBA    2015           9
# 79901      SFN  SFO03   WAS   SFN 2019-08-07    SFN    2019          -3
# 17433      MON  MON02   MON   SLN 1993-05-26    MON    1993           6
# 9733       MON  MON02   SLN   MON 1989-07-30    SLN    1989           5

# %%
formula = f"score_diff ~ {' + '.join(pca_col_names)} + visteam + hometeam + 0"
print(formula)
lr_model = ols(formula, data=df_train).fit()
# print(lr_model.params)
print(lr_model.summary())
# Out:
# score_diff ~ PCA_0 + PCA_1 + PCA_2 + PCA_3 + PCA_4 + visteam + hometeam + 0
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             score_diff   R-squared:                       0.185
# Model:                            OLS   Adj. R-squared:                  0
.3f}")
print(f"Mean Squared Error (MSE): {mse:.3f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.3f}")
print(f"Mean Absolute Error (MAE): {mae:.3f}")
# Out:
# R² Score: 0.183
# Mean Squared Error (MSE): 15.256
# Root Mean Squared Error (RMSE): 3.906
# Mean Absolute Error (MAE): 3.025

# %%
# try to predict a winner based on score_diff
df_test = df_test.assign(
    score_diff_pred = lr_model.predict(df_test)
)
correct_pred = 0
incorrect_pred = 0
for i, row in df_test.iterrows():
    if row['score_diff_pred'] > 0 and row['score_diff'] > 0:
        correct_pred += 1
    elif row['score_diff_pred'] < 0 and row['score_diff'] < 0:
        correct_pred += 1
    else:
        incorrect_pred += 1

print("Correct Predictions:", correct_pred, "Incorrect predictions:", incorrect_pred)
print("Percentage of correct pred (accuracy):", correct_pred / (correct_pred + incorrect_pred))
# Out:
# Correct Predictions: 12018 Incorrect predictions: 6224
# Percentage of correct pred (accuracy): 0.6588093410810218

# %% [markdown]
# using one hot encoding for `site`

# %%
site_dummies = pd.get_dummies(df_data['site'], prefix='site')
df_data_no_site = df_data[[col for col in df_data.columns if col != "site"]]

# combine new dataframes into one
df_data_site_onehot = pd.concat([df_data_no_site, site_dummies], axis=1)
# save df_data
df_data_site_onehot.to_csv("../CleanData/df_data_with_pca_site_onehot.csv", index=False)
df_data_site_onehot.head()
# Out:
#       PCA_0     PCA_1     PCA_2     PCA_3     PCA_4           gid visteam  \
# 0 -1.798157 -0.371419 -0.034352  0.946159  2.051056  BAL198504080     TEX
# 1 -1.030265 -0.507582 -0.129976  0.428520  1.706731  BOS198504080     NYA
# 2 -0.952697 -0.617817  2.435941 -0.058040  2.998030  CIN198504080     MON
# 3 -0.665617 -0.063812  1.663154  1.139868  2.024773  DET198504080     CLE
# 4 -1.757698  0.150974  0.860254  0.623820  1.532551  KCA198504080     TOR
#
#   hometeam wteam lteam  ... site_STL09 site_STL10  site_STP01  site_SYD01  \
# 0      BAL   BAL   TEX  ...      False      False       False       False
# 1      BOS   BOS   NYA  ...      False      False       False       False
# 2      CIN   CIN   MON  ...      False      False       False       False
# 3      DET   DET   CLE  ...      False      False       False       False
# 4      KCA   KCA   TOR  ...      False      False       False       False
#
#    site_TOK01  site_TOR01  site_TOR02  site_WAS10  site_WAS11  site_WIL02
# 0       False       False       False       False       False       False
# 1       False       False       False       False       False       False
# 2       False       False       False       False       False       False
# 3       False       False       False       False       False       False
# 4       False       False       False       False       False       False
#
# [5 rows x 86 columns]

# %%
df_train, df_test = train_test_split(df_data_site_onehot, test_size=0.2, random_state=123)
# train_data = pd.concat([X_train, y_train], axis=1)
df_train.head()
formula = f"score_diff ~ {' + '.join(pca_col_names)} + hometeam + visteam + yearID + 0"
print(formula)
lr_model = ols(formula, data=df_train).fit()
# print(lr_model.params)
print(lr_model.summary())

# %%
# try to predict a winner based on score_diff
df_test = df_test.assign(
    score_diff_pred = lr_model.predict(df_test)
)
correct_pred = 0
incorrect_pred = 0
for i, row in df_test.iterrows():
    if row['score_diff_pred'] > 0 and row['score_diff'] > 0:
        correct_pred += 1
    elif row['score_diff_pred'] < 0 and row['score_diff'] < 0:
        correct_pred += 1
    else:
        incorrect_pred += 1

print("Correct Predictions:", correct_pred, "Incorrect predictions:", incorrect_pred)
print("Percentage of correct pred:", correct_pred / (correct_pred + incorrect_pred))
# Out:
# Correct Predictions: 12018 Incorrect predictions: 6224
# Percentage of correct pred: 0.6588093410810218
